# %% [markdown]
# # Imports

# %%
import tensorflow as tf
from tensorflow import keras
from tensorflow.keras.preprocessing.text import Tokenizer
from tensorflow.keras.preprocessing.sequence import pad_sequences
import numpy as np

# %% [markdown]
# # Reading Dataset

# %%
import pandas as pd
df = pd.read_csv("traindata.csv")
df["tweet_content"].head()
# Out:
# 0    pics mexican school girl naked melanie safka f...
# 1    RT shereiqns Having curly hair is a gotdamn ch...
# 2     BreakingNews 7 Unexplained Prisoners Deaths M...
# 3     girl dirty quarterback latino pokemon young h...
# 4     miliondollameat sexting n ngirl daddy n nme l...
# Name: tweet_content, dtype: object

# %%
df["tweet_content"] = df["tweet_content"].str.lower()
df["tweet_content"] = df["tweet_content"].str.replace(r"[^a-z]+"," ")
df.head()
# Out:
#    Unnamed: 0                                      tweet_content  harassment  \
# 0           0  pics mexican school girl naked melanie safka f...           1
# 1           1  rt shereiqns having curly hair is a gotdamn ch...           0
# 2           2   breakingnews unexplained prisoners deaths mur...           0
# 3           3   girl dirty quarterback latino pokemon young h...           1
# 4           4   miliondollameat sexting n ngirl daddy n nme l...           1
#
#    IndirectH  PhysicalH  SexualH
# 0          0          0        1
# 1          0          0        0
# 2          0          0        0
# 3          0          0        1
# 4          0          0        1

# %% [markdown]
# ## Store our dataset into a list

# %%
data = list(df["tweet_content"])
len(data)
# Out:
# 6374

# %% [markdown]
# ## Store our labels into a list

# %%
labels = list(df["harassment"])
len(labels)
# Out:
# 6374

# %% [markdown]
# # Tokenizing our data

# %%
tokenizer = Tokenizer(oov_token="<OOV>")
tokenizer.fit_on_texts(data)
word_index = tokenizer.word_index
print(word_index)
# Out:
# {'<OOV>': 1, 'x': 2, 't': 3, 'a': 4, 'i': 5, 'amp': 6, 'co': 7, 'the': 8, 'slut': 9, 'rt': 10, 'to': 11, 's': 12, 'you': 13, 'and': 14, 'ava': 15, 'bitch': 16, 'is': 17, 'in': 18, 'for': 19, 'of': 20, 'my': 21, 'me': 22, 'she': 23, 'it': 24, 'that': 25, 'n': 26, 'm': 27, 'this': 28, 'girl': 29, 'girls': 30, 'on': 31, 'her': 32, 'like': 33, 'with': 34, 'd': 35, 'sassy': 36, 'fucking': 37, 'fuck': 38, 'all': 39, 'but': 40, 'be': 41, 'can': 42, 'so': 43, 'just': 44, 'are': 45, 'don': 46, 'about': 47, 'porn': 48, 'who': 49, 'if': 50, 'f': 51, 'was': 52, 'pussy': 53, 'what': 54, 'have': 55, 'out': 56, 'up': 57, 'we': 58, 'people': 59, 'your': 60, 'not': 61, 'when': 62, 'he': 63, 'being': 64, 'video': 65, 'at': 66, 're': 67, 'do': 68, 'cumshot': 69, 'they': 70, 'u': 71, 'little': 72, 'chopped': 73, 'ass': 74, 'love': 75, 'one': 76, 'as': 77, 'really': 78, 'shaming': 79, 'get': 80, 'sex': 81, 'or': 82, 'y': 83, 'horny': 84, 'because': 85, 'xxx': 86, 'videos': 87, 'no': 88, 'how': 89, 'their': 90, 'by': 91, 'women': 92, 'more': 93, 'now': 94, 'from': 95, 'black': 96, 'some': 97, 'naked': 98, 'good': 99, 'an': 100, 'time': 101, 'think': 102, 'still': 103, 'other': 104, 'w': 105, 'see': 106, 'there': 107, 'know': 108, 'want': 109, 'then': 110, 'his': 111, 'called': 112, 'always': 113, 'today': 114, 'these': 115, 'would': 116, '
# %%
train_data = padded[: -int(0.1*(len(padded)))]
test_data = padded[-int(0.1*(len(padded))):]
train_labels = labels[: -int(0.1*(len(padded)))]
test_labels = labels[-int(0.1*(len(padded))):]

len(train_data), len(test_data), len(train_labels), len(test_labels)
# Out:
# (5737, 637, 5737, 637)

# %% [markdown]
# # Creating our Keras model

# %%
vocab_size = 17000
max_len = 103
embedding_dim = 8

binary_model = tf.keras.Sequential([
    tf.keras.layers.Embedding(vocab_size, embedding_dim, input_length=max_len),
    tf.keras.layers.Flatten(),
    tf.keras.layers.Dense(6, activation="relu"),
    tf.keras.layers.Dense(1, activation="sigmoid")
])

# %% [markdown]
# # Compiling the model

# %%
binary_model.compile(loss="binary_crossentropy", optimizer="adam", metrics=["accuracy"])

# %% [markdown]
# # Model Summary

# %%
binary_model.summary()
# Out:
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# embedding_2 (Embedding)      (None, 103, 8)            136000
# _________________________________________________________________
# flatten_2 (Flatten)          (None, 824)               0
# _________________________________________________________________
# dense_4 (Dense)              (None, 6)                 4950
# _________________________________________________________________
# dense_5 (Dense)              (None, 1)                 7
# =================================================================
# Total params: 140,957
# Trainable params: 140,957
# Non-trainable params: 0
# _________________________________________________________________

# %% [markdown]
# # Training our model

# %%
num_epochs = 10
binary_model.fit(train_data, train_labels, epochs=num_epochs, validation_data=(test_data, test_labels))
# Out:
# /usr/local/lib/python3.6/dist-packages/tensorflow/python/ops/gradients_impl.py:108: UserWarning: Converting sparse IndexedSlices to a dense Tensor of unknown shape. This may consume a large amount of memory.
#   "Converting sparse IndexedSlices to a dense Tensor of unknown shape. "
# Train on 5737 samples, validate on 637 samples
# Epoch 1/10
# 5737/5737 [==============================] - 1s 190us/step - loss: 0.6794 - acc: 0.5756 - val_loss: 0.6728 - val_acc: 0.5620
# Epoch 2/10
# 5737/5737 [==============================] - 1s 124us/step - loss: 0.5727 - acc: 0.6636 - val_loss: 0.4478 - val_acc: 0.7865
# Epoch 3/10
# 5737/5737 [==============================] - 1s 127us/step - loss: 0.2778 - acc: 0.8999 - val_loss: 0.3113 - val_acc: 0.8728
# Epoch 4/10
# 5737/5737 [==============================] - 1s 121us/step - loss: 0.1573 - acc: 0.9463 - val_loss: 0.2911 - val_acc: 0.8932
# Epoch 5/10
# 5737/5737 [==============================] - 1s 122us/step - loss: 0.0957 - acc: 0.9711 - val_loss: 0.3134 - val_acc: 0.8666
# Epoch 6/10
# 5737/5737 [==============================] - 1s 135us/step - loss: 0.0599 - acc: 0.9854 - val_loss: 0.3222 - val_acc: 0.8760
# Epoch 7/10
# 5737/5737 [==============================] - 1s 123us/step - loss: 0.0397 - acc: 0.9913 - val_loss: 0.3361 - val_acc: 0.8697
# Epoch 8/10
# 5737/5737 [==============================] - 1s 148us/step - loss: 0.0286 - acc: 0.9930 - val_loss: 0.3343 - val_acc: 0.8791
# Epoch 9/10
# 5737/5737 [==============================] - 1s 122us/step - loss: 0.0216 - acc: 0.9946 - val_loss: 0.3581 - val_acc: 0.8666
# Epoch 10/10
# 5737/5737 [==============================] - 1s 146us/step - loss: 0.0170 - acc: 0.9946 - val_loss: 0.3597 - val_acc: 0.8728

# %%
from sklearn.metrics import classification_report

# %%
preds = binary_model.predict_classes(train_data)
preds
# Out:
# array([[1],
#        [0],
#        [0],
#        ...,
#        [0],
#        [0],
#        [0]], dtype=int32)

# %%
print(classification_report(y_pred=preds, y_true=train_labels))
# Out:
#               precision    recall  f1-score   support
#
#            0       1.00      0.99      1.00      3303
#            1       0.99      1.00      1.00      2434
#
#    micro avg       1.00      1.00      1.00      5737
#    macro avg       1.00      1.00      1.00      5737
# weighted avg       1.00      1.00      1.00      5737

# %%
def classify_binary(sentence):
    classes = {0: "non-harassment", 1: "harassment"}
    seq = tokenizer.texts_to_sequences([sentence])
    padded = pad_sequences(seq, padding="post", maxlen=103)
    return classes[binary_model.predict_classes(padded)[0][0]]

# %%
classify_binary("fuck you fucking dumb")
# Out:
# 'harassment'

# %%
classify_binary("I love you")
# Out:
# 'non-harassment'

# %% [markdown]
# # Preparing our harassment data for Categorical Classification

# %%
X = []
y = []

for sentence, h, indirect, physical, sexual in zip(df["tweet_content"], df["harassment"],df["IndirectH"],df["PhysicalH"], df["SexualH"]):
    if h:
        X.append(sentence)
        if indirect:
            y.append(0)
        elif physical:
            y.append(1)
        else:
            y.append(2)

# %%
len(X), len(y)
# Out:
# (2713, 2713)

# %% [markdown]
# ## One Hot Encoding our labels

# %%
from sklearn.preprocessing import OneHotEncoder

enc = OneHotEncoder(handle_unkn
45, 80, 41, 231, 2921], [49, 319, 60, 6, 40, 2, 251, 1068, 34, 18, 20, 181, 320, 60, 458, 353, 181, 6], [425, 35, 426, 103, 1319, 101, 28, 51, 273, 199, 2922, 5, 3, 8, 2923, 2924], [11, 2925, 18, 31, 198, 781, 12, 529, 263, 106, 147, 782, 427, 7, 300, 23, 459, 58, 30, 264, 686, 58, 263, 26, 563, 11, 84, 564], [20, 6, 150, 77, 1320, 78, 301, 167, 2, 897, 275, 9, 2926, 7, 97, 9], [2927, 9, 5, 71, 284, 2928, 28, 783, 302, 187, 5, 3, 187, 5, 3, 5, 3, 8, 2929], [2930, 2931, 2932, 1321, 7, 32, 276, 19, 4, 2933, 14, 1786, 223, 2934, 1787, 17, 688, 2, 265, 428, 689, 301], [1069, 2935, 2936, 29, 565, 60, 483, 16, 10, 898, 18, 9, 2937, 7, 46, 117, 1070, 4, 6, 2, 79, 4, 1322], [2938, 2, 55, 1788, 784, 1071, 785, 367, 12, 367, 1072], [125, 899, 81, 460, 1789, 530, 566, 47, 40, 1790, 461, 126, 120], [272, 1323, 25, 35, 120, 3, 8, 2939, 2940, 2941], [1791, 15, 106, 429, 106, 9, 56, 3, 150, 65, 14, 4, 125, 531, 79, 2942, 54, 400, 65, 337, 3, 2, 98, 60, 12, 168, 285, 77, 2943], [2944, 10, 426, 567, 29, 4, 2, 9, 690, 148, 12, 4, 303, 2945, 24, 4, 785, 29, 900, 27, 138, 532, 12, 901, 430, 427, 38, 902, 223], [9, 71, 6, 5, 2, 266, 174, 3, 8, 2946, 1792, 2947], [2948, 104, 462, 1793, 1324, 1794, 2, 1073, 1795, 354, 5, 3, 401, 29, 5], [10, 104, 23, 533, 24, 10, 2949, 1325, 57, 39, 1326, 137, 262, 113, 67, 37, 15, 23, 1327, 24, 124, 206], [2950, ...

# %% [markdown]
# ## Padding our Sequences

# %%
padded = pad_sequences(sequences, padding="post")
print(padded)
# Out:
# [[ 314 1056  152 ...    0    0    0]
#  [  15  158 1746 ...    0    0    0]
#  [2863  350   27 ...    0    0    0]
#  ...
#  [  37    6  131 ...    0    0    0]
#  [  24  470   36 ...    0    0    0]
#  [ 303   86   41 ...    0    0    0]]

# %% [markdown]
# ## Splitting our dataset into Train set & Validation set

# %%
train_data = padded[: -int(0.15*(len(padded)))]
test_data = padded[-int(0.15*(len(padded))):]
train_labels = y[: -int(0.15*(len(padded)))]
test_labels = y[-int(0.15*(len(padded))):]

len(train_data), len(test_data), len(train_labels), len(test_labels)
# Out:
# (2307, 406, 2307, 406)

# %%
len(padded[0])
# Out:
# 32

# %% [markdown]
# ## Creating our Model for Categorical Classification

# %%
vocab_size = 8000
max_len = 32
embedding_dim = 8

categorical_model = tf.keras.Sequential([
    tf.keras.layers.Embedding(vocab_size, embedding_dim, input_length=max_len),
    tf.keras.layers.Flatten(),
    tf.keras.layers.Dense(8, activation="relu"),
    tf.keras.layers.Dense(3, activation="softmax")
])

# %% [markdown]
# ## Compiling our model

# %%
categorical_model.compile(loss="categorical_crossentropy", optimizer="adam", metrics=["accuracy"])

# %%
num_epochs = 10
categorical_model.fit(train_data, train_labels, epochs=num_epochs, validation_data=(test_data, test_labels))
# Out:
# /usr/local/lib/python3.6/dist-packages/tensorflow/python/ops/gradients_impl.py:108: UserWarning: Converting sparse IndexedSlices to a dense Tensor of unknown shape. This may consume a large amount of memory.
#   "Converting sparse IndexedSlices to a dense Tensor of unknown shape. "
# Train on 2307 samples, validate on 406 samples
# Epoch 1/10
# 2307/2307 [==============================] - 1s 266us/step - loss: 0.7766 - acc: 0.8934 - val_loss: 0.3020 - val_acc: 0.9507
# Epoch 2/10
# 2307/2307 [==============================] - 0s 141us/step - loss: 0.2293 - acc: 0.9519 - val_loss: 0.2259 - val_acc: 0.9507
# Epoch 3/10
# 2307/2307 [==============================] - 0s 130us/step - loss: 0.2106 - acc: 0.9519 - val_loss: 0.2239 - val_acc: 0.9507
# Epoch 4/10
# 2307/2307 [==============================] - 0s 135us/step - loss: 0.1957 - acc: 0.9519 - val_loss: 0.2230 - val_acc: 0.9507
# Epoch 5/10
# 2307/2307 [==============================] - 0s 147us/step - loss: 0.1790 - acc: 0.9519 - val_loss: 0.2205 - val_acc: 0.9507
# Epoch 6/10
# 2307/2307 [==============================] - 0s 144us/step - loss: 0.1574 - acc: 0.9519 - val_loss: 0.2196 - val_acc: 0.9507
# Epoch 7/10
# 2307/2307 [==============================] - 0s 137us/step - loss: 0.1323 - acc: 0.9519 - val_loss: 0.2179 - val_acc: 0.9507
# Epoch 8/10
# 2307/2307 [==============================] - 0s 120us/step - loss: 0.1063 - acc: 0.9536 - val_loss: 0.2215 - val_acc: 0.9507
# Epoch 9/10
# 2307/2307 [==============================] - 0s 128us/step - loss: 0.0798 - acc: 0.9679 - val_loss: 0.2292 - val_acc: 0.9507
# Epoch 10/10
# 2307/2307 [==============================] - 0s 165us/step - loss: 0.0555 - acc: 0.9775 - val_loss: 0.2382 - val_acc: 0.9507

# %% [markdown]
# ## Categorical Classification

# %%
def classify_categorical(sentence):
    classes = {0:"Indirect Harassment",1:"Physical Harassment", 2:"Sexual Harassment"}
    seq = tokenizer.texts_to_sequences([sentence])
    padded = pad_sequences(seq, padding="post", maxlen=32)
    return classes[categorical_model.predict_classes(padded)[0]]

# %%
classify_categorical("fuck you")
# Out:
# 'Sexual Harassment'

# %%
classify_categorical("The woman brutally tortured minor servant starved MAJOR AMMARA")
# Out:
# 'Physical Harassment'

# %% [markdown]
# ## Full classification

# %%
def classify(sentence):
    h = classify_binary(sentence)
    if h == "harassment":
        h_type = classify_categorical(sentence)
        return h + ": " + h_type
    else:
        return h

# %%
sample = "I hate you and I will kill you with my gun and bury your body"
classify(sample)
# Out:
# 'harassment: Sexual Harassment'

# %%
sample = "too much love"
classify(sample)
# Out:
# 'non-harassment'

# %% [markdown]
# ## Saving predictions to CSV

# %%
def get_preds(sentence):
    pred = []
    classes = {"Indirect Harassment":[1,0,0], "Physical Harassment":[0,1,0], "Sexual Harassment":[0,0,1]}
    h = classify_binary(sentence)
    if h == "harassment":
        pred += [sentence, 1]
        h_type = classify_categorical(sentence)
        pred += classes[h_type]
    else:
        pred = [sentence,0,0,0,0]
    return pred

# %%
get_preds("too much love")
# Out:
# ['too much love', 0, 0, 0, 0]

# %%
get_preds("I will screw you")
# Out:
# ['I will screw you', 1, 0, 0, 1]

# %%
preds = []

for sent in df["tweet_content"]:
    preds.append(get_preds(sent))

# %%
import csv

with open('results.csv', 'w') as writeFile:
    writer = csv.writer(writeFile)
    writer.writerows(preds)
